# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv("weatherAUS.csv", sep=",")
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
dataset.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#dataset.groupby("Evaporation").size()
#dataset.duplicated().sum()
#dataset.info()
dataset.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
dataset.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
dataset.dropna(inplace=True)

# %%
dataset.reset_index(drop=True)
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 1      2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 2      2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 3      2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 4      2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
# ...           ...      ...      ...      ...       ...          ...       ...
# 56415  2017-06-20   Darwin     19.3     33.4       0.0          6.0      11.0
# 56416  2017-06-21   Darwin     21.2     32.6       0.0          7.6       8.6
# 56417  2017-06-22   Darwin     20.7     32.8       0.0          5.6      11.0
# 56418  2017-06-23   Darwin     19.5     31.8       0.0          6.2      10.6
# 56419  2017-06-24   Darwin     20.2     31.7       0.0          5.6      10.7
#
# ...

# %%
dataset.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
dataset = dataset.drop(columns="Date", axis=1)

# %%
range(0,len(dataset.columns),1)
# Out:
# range(0, 22)

# %%
numerical_cols = dataset.select_dtypes(include=['float64', 'int64']).columns

#Calculate Q1, Q3, and IQR for the numerical columns
Q1 = dataset[numerical_cols].quantile(0.25)
Q3 = dataset[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

# Define the bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to remove outliers
df_no_outliers = dataset[~((dataset[numerical_cols] < lower_bound) | (dataset[numerical_cols] > upper_bound)).any(axis=1)]
df_no_outliers
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049      Cobar     17.9     35.2       0.0         12.0      12.3
# 6052      Cobar     19.4     37.6       0.0         10.8      10.6
# 6053      Cobar     21.9     38.4       0.0         11.4      12.2
# 6054      Cobar     24.2     41.0       0.0         11.2       8.4
# 6055      Cobar     27.1     36.1       0.0         13.0       0.0
# ...         ...      ...      ...       ...          ...       ...
# 142298   Darwin     19.3     33.4       0.0          6.0      11.0
# 142299   Darwin     21.2     32.6       0.0          7.6       8.6
# 142300   Darwin     20.7     32.8       0.0          5.6      11.0
# 142301   Darwin     19.5     31.8       0.0          6.2      10.6
# 142302   Darwin     20.2     31.7       0.0          5.6      10.7
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 6049           SSW           48.0        ENE         SW  ...         20.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

StandardScaler = StandardScaler()
int_columns = df_no_outliers.select_dtypes(include=["int64", "float64"]).columns
int_columns

for column in int_columns:
    df_no_outliers.loc[:,column] =   StandardScaler.fit_transform(df_no_outliers.loc[:, column].values.reshape(-1, 1))

# %%
df_no_outliers
# Out:
#        Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049      Cobar  0.740056  1.609849 -0.386229     2.152373  1.130410
# 6052      Cobar  0.972667  1.974703 -0.386229     1.755862  0.649802
# 6053      Cobar  1.360352  2.096321 -0.386229     1.954117  1.102139
# 6054      Cobar  1.717023  2.491579 -0.386229     1.888032  0.027839
# 6055      Cobar  2.166738  1.746669 -0.386229     2.482798 -2.346930
# ...         ...       ...       ...       ...          ...       ...
# 142298   Darwin  0.957160  1.336209 -0.386229     0.169820  0.762886
# 142299   Darwin  1.251800  1.214591 -0.386229     0.698500  0.084381
# 142300   Darwin  1.174263  1.244995 -0.386229     0.037649  0.762886
# 142301   Darwin  0.988174  1.092973 -0.386229     0.235905  0.649802
# 142302   Darwin  1.096726  1.077771 -0.386229     0.037649  0.678073
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

LabelEncoder = LabelEncoder()
for column in df_no_outliers.columns:
    if df_no_outliers[column].dtype == "object":
        df_no_outliers[column] = LabelEncoder.fit_transform(df_no_outliers[column])
# Out:
# /tmp/ipykernel_489905/471212314.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers[column] = LabelEncoder.fit_transform(df_no_outliers[column])
# /tmp/ipykernel_489905/471212314.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers[column] = LabelEncoder.fit_transform(df_no_outliers[column])
# /tmp/ipykernel_489905/471212314.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dataset_scaled = pd.DataFrame(df_no_outliers, columns=df_no_outliers.columns)
dataset_scaled
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049           4  0.740056  1.609849 -0.386229     2.152373  1.130410
# 6052           4  0.972667  1.974703 -0.386229     1.755862  0.649802
# 6053           4  1.360352  2.096321 -0.386229     1.954117  1.102139
# 6054           4  1.717023  2.491579 -0.386229     1.888032  0.027839
# 6055           4  2.166738  1.746669 -0.386229     2.482798 -2.346930
# ...          ...       ...       ...       ...          ...       ...
# 142298         6  0.957160  1.336209 -0.386229     0.169820  0.762886
# 142299         6  1.251800  1.214591 -0.386229     0.698500  0.084381
# 142300         6  1.174263  1.244995 -0.386229     0.037649  0.762886
# 142301         6  0.988174  1.092973 -0.386229     0.235905  0.649802
# 142302         6  1.096726  1.077771 -0.386229     0.037649  0.678073
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# ...

# %%
dataset_scaled.describe()
# Out:
#            Location       MinTemp       MaxTemp      Rainfall   Evaporation  \
# count  41723.000000  4.172300e+04  4.172300e+04  4.172300e+04  4.172300e+04
# mean      12.698512  1.416896e-16 -2.043600e-16  5.585840e-17  1.226160e-16
# std        7.273882  1.000012e+00  1.000012e+00  1.000012e+00  1.000012e+00
# min        0.000000 -2.935200e+00 -3.118046e+00 -3.862294e-01 -1.812734e+00
# 25%        7.000000 -7.641630e-01 -7.769019e-01 -3.862294e-01 -7.553720e-01
# 50%       13.000000 -3.531473e-02 -1.679012e-02 -3.862294e-01 -9.452089e-02
# 75%       19.000000  7.710706e-01  7.889283e-01 -3.862294e-01  6.985004e-01
# max       25.000000  2.569930e+00  3.130072e+00  4.998843e+00  2.912352e+00
#
#            Sunshine   WindGustDir  WindGustSpeed    WindDir9am    WindDir3pm  \
# count  4.172300e+04  41723.000000   4.172300e+04  41723.000000  41723.000000
# mean  -3.215264e-16      7.133715   1.220200e-16      6.809601      7.251588
# ...

# %%
df_no_outliers.to_csv('dataset_scaled_no_outliers.csv', sep=',', encoding='utf-8', index = False)
